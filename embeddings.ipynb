# %%
# pip install langchain
# pip install sentence-transformers

# %%
import os
from pathlib import Path
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer
import torch
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/utils/import_utils.py:1968, in _LazyModule._get_module(self, module_name)
#    1967 try:
# -> 1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
#
# File ~/miniforge3/envs/nlp/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:38
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/activations_tf.py:27
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/utils/import_utils.py:1968, in _LazyModule._get_module(self, module_name)
#    1967 try:
# -> 1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
#
# File ~/miniforge3/envs/nlp/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/integrations/integration_utils.py:36
#      34 import packaging.version
# ---> 36 from .. import PreTrainedModel, TFPreTrainedModel
#      37 from .. import __version__ as version
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/utils/import_utils.py:1956, in _LazyModule.__getattr__(self, name)
#    1955 elif name in self._class_to_module.keys():
# -> 1956     module = self._get_module(self._class_to_module[name])
#    1957     value = getattr(module, name)
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/utils/import_utils.py:1970, in _LazyModule._get_module(self, module_name)
#    1969 except Exception as e:
# -> 1970     raise RuntimeError(
#    1971         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1972         f" traceback):\n{e}"
#    1973     ) from e
#
# RuntimeError: Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 5
#       3 from langchain.docstore.document import Document
#       4 from langchain.text_splitter import RecursiveCharacterTextSplitter
# ----> 5 from sentence_transformers import SentenceTransformer
#       6 import torch
#       7 import numpy as np
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/__init__.py:14
#       7 import os
#       9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#      17     CrossEncoderTrainer,
#      18     CrossEncoderTrainingArguments,
#      19 )
#      20 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      21 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/cross_encoder/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:31
#      28 from typing_extensions import deprecated
#      30 from sentence_transformers import __version__
# ---> 31 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      32 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      33 from sentence_transformers.cross_encoder.util import (
#      34     cross_encoder_init_args_decorator,
#      35     cross_encoder_predict_rank_args_decorator,
#      36 )
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/cross_encoder/fit_mixin.py:19
#      16 from transformers.tokenization_utils_base import BatchEncoding
#      18 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
# ---> 19 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
#      20 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      21 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/datasets/__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/datasets/ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:34
#      31 from transformers import is_torch_npu_available
#      32 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
# ---> 34 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      35 from sentence_transformers.similarity_functions import SimilarityFunction
#      37 from . import __MODEL_HUB_ORGANIZATION__, __version__
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/sentence_transformers/model_card.py:25
#      23 from tqdm.autonotebook import tqdm
#      24 from transformers import TrainerCallback
# ---> 25 from transformers.integrations import CodeCarbonCallback
#      26 from transformers.modelcard import make_markdown_table
#      27 from transformers.trainer_callback import TrainerControl, TrainerState
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/utils/import_utils.py:1956, in _LazyModule.__getattr__(self, name)
#    1954     value = Placeholder
#    1955 elif name in self._class_to_module.keys():
# -> 1956     module = self._get_module(self._class_to_module[name])
#    1957     value = getattr(module, name)
#    1958 elif name in self._modules:
#
# File ~/miniforge3/envs/nlp/lib/python3.11/site-packages/transformers/utils/import_utils.py:1970, in _LazyModule._get_module(self, module_name)
#    1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
# -> 1970     raise RuntimeError(
#    1971         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1972         f" traceback):\n{e}"
#    1973     ) from e
#
# RuntimeError: Failed to import transformers.integrations.integration_utils because of the following error (look up to see its traceback):
# Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %%
# --- Embedding Wrapper (from earlier) ---
class LangchainSentenceTransformer:
    def __init__(self, model_name: str = "mixedbread-ai/mxbai-embed-large-v1"):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model = SentenceTransformer(model_name).to(self.device)
        self.query_prefix = "Represent this sentence for searching relevant passages: "
        self._cleaned_documents = []

    def embed_documents(self, documents: list[Document]) -> tuple[list[str], np.ndarray]:
        # Simple filter to drop empty or irrelevant chunks
        bad_substrings = ["Atomic Structure Representation", "Logical path\nD\nF\nC\nA\nE"]
        filtered: list[Document] = []
        for doc in documents:
            text = doc.page_content.strip()
            if text and not any(bad in text for bad in bad_substrings):
                filtered.append(Document(page_content=text, metadata=doc.metadata))
        self._cleaned_documents = filtered
        texts = [d.page_content for d in filtered]

        # Encode all chunks
        embeddings = self.model.encode(
            texts,
            show_progress_bar=True,
            convert_to_numpy=True,
            device=self.device
        )
        return texts, embeddings

    def embed_query(self, query: str) -> np.ndarray:
        return self.model.encode(
            [self.query_prefix + query],
            convert_to_numpy=True,
            device=self.device
        )[0]

# --- Configuration ---
ROOT_DIR = Path("clean_txt")     # root folder containing subfolders '02', '03', ..., '12'
CHUNK_SIZE = 1000
overlap = 200

# --- Collect Documents ---
all_docs: list[Document] = []
for month_dir in sorted(ROOT_DIR.iterdir()):
    if not month_dir.is_dir():
        continue
    for txt_file in sorted(month_dir.glob("*.txt")):
        text = txt_file.read_text(encoding="utf-8")
        # store metadata if desired
        meta = {"file": txt_file.stem, "month": month_dir.name}
        all_docs.append(Document(page_content=text, metadata=meta))

print(f"[INFO] Loaded {len(all_docs)} source documents.")

# --- Chunking ---
splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE,
    chunk_overlap=overlap
)
chunked_docs: list[Document] = []
for doc in all_docs:
    chunks = splitter.split_documents([doc])
    chunked_docs.extend(chunks)
print(f"[INFO] Split into {len(chunked_docs)} chunks of ~{CHUNK_SIZE} chars each.")

# --- Embedding ---
embedder = LangchainSentenceTransformer()
texts, embeddings = embedder.embed_documents(chunked_docs)
print(f"[INFO] Produced {len(texts)} embeddings of dimension {embeddings.shape[1]}")

# --- (Optional) Save embeddings for later ---
# np.savez_compressed("fallos_embeddings.npz", texts=texts, embeddings=embeddings)

# Now `texts` and `embeddings` are ready for indexing in FAISS or pgvector.
