# %%
import json
from pathlib import Path
from collections import Counter
import os

def extract_main_sources_from_json_files(base_path):
    """
    Extrae todos los valores únicos de 'main_source' de los archivos JSON
    en la estructura de carpetas por mes.
    
    Args:
        base_path: Ruta base donde están las carpetas de meses (ej: 'datasets/unified_json')
    
    Returns:
        set: Conjunto de valores únicos de main_source
        Counter: Contador de frecuencias de cada main_source
    """
    base_path = Path(base_path)
    main_sources = set()
    main_source_counter = Counter()
    
    # Recorrer todas las carpetas de meses
    for month_folder in sorted(base_path.iterdir()):
        if not month_folder.is_dir():
            continue
            
        print(f"Procesando mes: {month_folder.name}")
        
        # Recorrer todos los archivos JSON en cada mes
        for json_file in month_folder.glob("*.json"):
            try:
                with open(json_file, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                
                # Extraer main_sources de ARTICULOS_CITADOS
                articulos_citados = data.get("METADATOS", {}).get("ARTICULOS_CITADOS", {})
                citations = articulos_citados.get("citations", [])
                
                for citation in citations:
                    main_source = citation.get("main_source", "")
                    if main_source and main_source.strip():
                        main_sources.add(main_source)
                        main_source_counter[main_source] += 1
                        
            except Exception as e:
                print(f"Error procesando {json_file}: {e}")
    
    return main_sources, main_source_counter



# Usar la ruta de tu workspace
base_path = Path(os.path.dirname(os.getcwd())) / "datasets" / "unified_json"  # Ajusta esta ruta según tu estructura

print("🔍 Extrayendo valores de 'main_source' de archivos JSON...")

main_sources, counter = extract_main_sources_from_json_files(base_path)

print(f"\n📊 RESULTADOS:")
print(f"Total de 'main_source' únicos encontrados: {len(main_sources)}")
print(f"Total de citas procesadas: {sum(counter.values())}")

print(f"\n📋 LISTA DE MAIN_SOURCES ÚNICOS:")
for i, source in enumerate(sorted(main_sources), 1):
    print(f"{i:2d}. {source}")

print(f"\n📈 FRECUENCIA DE MAIN_SOURCES (Top 10):")
for source, count in counter.most_common(10):
    print(f"  • {source}: {count} citas")
# Out:
# 🔍 Extrayendo valores de 'main_source' de archivos JSON...
# Procesando mes: 02
# Procesando mes: 03
# Procesando mes: 04
# Procesando mes: 05
# Procesando mes: 06
# Procesando mes: 07
# Procesando mes: 08
# Procesando mes: 09
# Procesando mes: 10
# Procesando mes: 11
# Procesando mes: 12
#
# 📊 RESULTADOS:
# Total de 'main_source' únicos encontrados: 126
# Total de citas procesadas: 635
#
# 📋 LISTA DE MAIN_SOURCES ÚNICOS:
#  1. Ac. Gral. 15/18 SNE
#  2. Ac. N° 4/2007
#  3. Acordada 15/18 SNE
#  4. Acordada General Nº 28/15
#  5. Acordada General del S.T.J.E.R.
#  6. Acuerdo General 11/20
#  7. Acuerdo General 15/18 SNE
#  8. Acuerdo General 28/20
#  9. Acuerdo General N° 14/24
# 10. Acuerdo General N° 28/15
# 11. Acuerdo Gral.
# 12. Acuerdo Gral. 11/20
# 13. Acuerdo Gral. 11/20 del 23-6-2020
# 14. Aranda, Raúl Eduardo c/ ENA (Min. de Def. - Ejército Argentino) y/o Q.R.R. s/ impugnación de acto administrativo
# 15. Baldwin, Elina Dorotea c/Metrovias S.A. s/ daños y perjuicios
# 16. C.N.
# 17. C.P.C.C
# 18. CCC
# 19. CCCN
# 20. CN
# 21. CPCC
# 22. CPP
# 23. CSJN
# 24. Const. Nac.
# 25. Constitución Nacional
# 26. Constitución Nacional (CN)
# 27. Constitución Provincial
# 28. Constitución de Entre Ríos
# 29. Convención Americana de Derechos Humanos
# 30. Convención sobre los Derechos de las Personas Adultas Mayores
# 31. Convención sobre los Derechos del Niño
# 32. Corte Interamericana de Derechos Humanos
# 33. Corte Suprema de Justicia de la Nación
# 34. Cámara
# 35. Código Civil
# 36. Código Civil y Comercial
# 37. Código Civil y Comercial (CCC)
# 38. Código Civil y Comercial de la Nación
# 39. Código Procesal Civil y Comercial
# 40. Código Procesal Civil y Comercial (CPCC)
# 41. Código Procesal Civil y Comercial de Entre Ríos
# 42. Código Procesal Civil y Comercial de Entre Ríos (CPCCER)
# 43. Código de forma
# 44. Código de rito
# 45. DL 5.963
# 46. Decreto reglamentario 958/79 y modificatorios
# 47. Expte. Nº 4140
# 48. Expte. Nº 4142
# 49. Expte. Nº 4247
# 50. Expte. Nº 6381
# 51. Expte. Nº 8713
# 52. Fallos
# 53. Guía de Buenas Prácticas
# 54. L.A.S.
# 55. L.C.Q.
# 56. L.F.
# 57. L.F. N° 10889
# 58. LA
# 59. LCQ
# 60. LEY 23737
# 61. LEY DE DEFENSA CONSUMIDOR
# 62. LF nro. 11843 S/ INCIDENTE COMPETENCIA
# 63. LOPJ
# 64. LPF
# 65. LS
# 66. Ley 10.636
# 67. Ley 10.855
# 68. Ley 10025
# 69. Ley 10668
# 70. Ley 11.151
# 71. Ley 14.159
# 72. Ley 24.449
# 73. Ley 24.522
# 74. Ley 24449
# 75. Ley 26.485
# 76. Ley 26.487
# 77. Ley 26061
# 78. Ley 27.440
# 79. Ley 27423
# 80. Ley 48
# 81. Ley 4878
# 82. Ley 5796
# 83. Ley 7046
# 84. Ley 9776
# 85. Ley Arancelaria
# 86. Ley Nacional de Tránsito (LNT)
# 87. Ley Nacional de Tránsito Nro. 24.449
# 88. Ley Nº 9234
# 89. Ley Orgánica de las cuestiones de competencia
# 90. Ley Orgánica del Poder Judicial (LOPJ)
# 91. Ley Orgánica del Poder Judicial - Ley 6902
# 92. Ley Procesal de Familia
# 93. Ley Procesal de Familia (Ley Provincial 10.668)
# 94. Ley Prov. 9.861
# 95. Ley de Protección Integral de los Derechos de las Niñas, Niños y Adolescentes (Ley Nacional 26.061)
# 96. Ley de Protección Integral de los Derechos del Niño, el Adolescente y la Familia (Ley Provincial 9.861)
# 97. Ley provincial 6.351
# 98. Ordenamiento Procesal
# 99. Ordenanza Municipal 17376
# 100. Pacto de San José de Costa Rica
# 101. Procedimiento de intervención del Organismo de Protección de Derechos de la Provincia de Entre Ríos (Resolución 170/19)
# 102. Reglamento de Presentaciones Electrónicas
# 103. Resol. Trib. Sup. 340/2023 DGA
# 104. URBANOTEC S.A. S/ QUIEBRA
# 105. código civil
# 106. código civil y comercial
# 107. código procesal civil y comercial
# 108. ley 10.407
# 109. ley 10.704
# 110. ley 10.956
# 111. ley 19.550
# 112. ley 25.529
# 113. ley 26.485
# 114. ley 26.657
# 115. ley 48
# 116. ley 6902
# 117. ley 7046
# 118. ley 7504
# 119. ley arancelaria
# 120. ley de aranceles
# 121. ley de honorarios profesionales
# 122. ordenamiento de forma local
# 123. resolución
# 124. sentencia
# 125. texto según ley 10.704
# 126. unknown
#
# 📈 FRECUENCIA DE MAIN_SOURCES (Top 10):
#   • Ac. Gral. 15/18 SNE: 85 citas
#   • Acuerdo Gral. 11/20: 73 citas
#   • LOPJ: 70 citas
#   • CPCC: 69 citas
#   • unknown: 43 citas
#   • ley 10.704: 32 citas
#   • ley 7046: 27 citas
#   • Constitución Provincial: 16 citas
#   • CPP: 11 citas
#   • Código Procesal Civil y Comercial: 9 citas

# %%
# Imprimir lista completa con frecuencias
print(f"\n📊 LISTA COMPLETA CON FRECUENCIAS:")
print("=" * 60)
for source, count in counter.most_common():
    print(f"{source}: {count}")
# Out:
# 📊 LISTA COMPLETA CON FRECUENCIAS:
# ============================================================
# Ac. Gral. 15/18 SNE: 85
# Acuerdo Gral. 11/20: 73
# LOPJ: 70
# CPCC: 69
# unknown: 43
# ley 10.704: 32
# ley 7046: 27
# Constitución Provincial: 16
# CPP: 11
# Código Procesal Civil y Comercial: 9
# Código Civil y Comercial: 9
# CCC: 9
# CN: 7
# Acordada 15/18 SNE: 7
# Código Civil: 6
# Constitución Nacional: 6
# Código Civil y Comercial (CCC): 5
# Código Procesal Civil y Comercial de Entre Ríos (CPCCER): 5
# ley 48: 5
# LCQ: 4
# Fallos: 4
# LPF: 4
# Código Procesal Civil y Comercial (CPCC): 3
# Acuerdo General 15/18 SNE: 3
# Acuerdo General 11/20: 3
# Ley Orgánica del Poder Judicial - Ley 6902: 3
# Constitución Nacional (CN): 3
# L.C.Q.: 3
# resolución: 3
# Ordenamiento Procesal: 2
# Ley 7046: 2
# C.N.: 2
# Ley Procesal de Familia: 2
# Ley Orgánica del Poder Judicial (LOPJ): 2
# ley 6902: 2
# ley 26.485: 2
# CSJN: 2
# Convención Americana de Derechos Humanos: 2
# Convención sobre los Derechos de las Personas Adultas Mayores: 2
# L.A.S.: 2
# Ley Nacional de Tránsito Nro. 24.449: 1
# Ley 24449: 1
# Ley 10025: 1
# Corte Suprema de Justicia de la Nación: 1
# Ley Nacional de Tránsito (LNT): 1
# Ley 24.449: 1
# Ordenanza Municipal 17376: 1
# ley 19.550: 1
# Ley 24.522: 1
# URBANOTEC S.A. S/ QUIEBRA: 1
# LF nro. 11843 S/ INCIDENTE COMPETENCIA: 1
# Baldwin, Elina Dorotea c/Metrovias S.A. s/ daños y perjuicios: 1
# Aranda, Raúl Eduardo c/ ENA (Min. de Def. - Ejército Argentino) y/o Q.R.R. s/ impugnación de acto administrativo: 1
# Acuerdo General 28/20: 1
# Acordada General Nº 28/15: 1
# LEY 23737: 1
# Ley 10.636: 1
# Ley 5796: 1
# Ley 48: 1
# código civil y comercial: 1
# código civil: 1
# código procesal civil y comercial: 1
# Código de forma: 1
# Ac. N° 4/2007: 1
# Código Procesal Civil y Comercial de Entre Ríos: 1
# Pacto de San José de Costa Rica: 1
# ley 25.529: 1
# Expte. Nº 6381: 1
# Ley 4878: 1
# Ley 27423: 1
# Ley 9776: 1
# Ley 10668: 1
# Ley 26.485: 1
# Ley 10.855: 1
# Ley de Protección Integral de los Derechos del Niño, el Adolescente y la Familia (Ley Provincial 9.861): 1
# Ley de Protección Integral de los Derechos de las Niñas, Niños y Adolescentes (Ley Nacional 26.061): 1
# Código Civil y Comercial de la Nación: 1
# Ley Procesal de Familia (Ley Provincial 10.668): 1
# Procedimiento de intervención del Organismo de Protección de Derechos de la Provincia de Entre Ríos (Resolución 170/19): 1
# Acuerdo Gral. 11/20 del 23-6-2020: 1
# LA: 1
# Reglamento de Presentaciones Electrónicas: 1
# Constitución de Entre Ríos: 1
# ordenamiento de forma local: 1
# ley 10.956: 1
# ley 10.407: 1
# Ley Orgánica de las cuestiones de competencia: 1
# Resol. Trib. Sup. 340/2023 DGA: 1
# LEY DE DEFENSA CONSUMIDOR: 1
# L.F. N° 10889: 1
# Ley 14.159: 1
# texto según ley 10.704: 1
# Código de rito: 1
# ley de honorarios profesionales: 1
# Const. Nac.: 1
# Convención sobre los Derechos del Niño: 1
# Guía de Buenas Prácticas: 1
# Corte Interamericana de Derechos Humanos: 1
# Ley 26061: 1
# Ley 26.487: 1
# CCCN: 1
# L.F.: 1
# C.P.C.C: 1
# Expte. Nº 8713: 1
# Expte. Nº 4142: 1
# Expte. Nº 4140: 1
# Expte. Nº 4247: 1
# sentencia: 1
# Cámara: 1
# ley 7504: 1
# Acordada General del S.T.J.E.R.: 1
# Acuerdo General N° 14/24: 1
# Acuerdo General N° 28/15: 1
# Acuerdo Gral.: 1
# ley arancelaria: 1
# ley de aranceles: 1
# LS: 1
# Ley provincial 6.351: 1
# Decreto reglamentario 958/79 y modificatorios: 1
# Ley 27.440: 1
# DL 5.963: 1
# Ley 11.151: 1
# Ley Arancelaria: 1
# Ley Prov. 9.861: 1
# ley 26.657: 1
# Ley Nº 9234: 1

# %%
# Imprimir lista única sin frecuencias
print(f"\n📝 LISTA ÚNICA SIN FRECUENCIAS:")
print("=" * 60)
for source in sorted(main_sources):
    print(source)
# Out:
# 📝 LISTA ÚNICA SIN FRECUENCIAS:
# ============================================================
# Ac. Gral. 15/18 SNE
# Ac. N° 4/2007
# Acordada 15/18 SNE
# Acordada General Nº 28/15
# Acordada General del S.T.J.E.R.
# Acuerdo General 11/20
# Acuerdo General 15/18 SNE
# Acuerdo General 28/20
# Acuerdo General N° 14/24
# Acuerdo General N° 28/15
# Acuerdo Gral.
# Acuerdo Gral. 11/20
# Acuerdo Gral. 11/20 del 23-6-2020
# Aranda, Raúl Eduardo c/ ENA (Min. de Def. - Ejército Argentino) y/o Q.R.R. s/ impugnación de acto administrativo
# Baldwin, Elina Dorotea c/Metrovias S.A. s/ daños y perjuicios
# C.N.
# C.P.C.C
# CCC
# CCCN
# CN
# CPCC
# CPP
# CSJN
# Const. Nac.
# Constitución Nacional
# Constitución Nacional (CN)
# Constitución Provincial
# Constitución de Entre Ríos
# Convención Americana de Derechos Humanos
# Convención sobre los Derechos de las Personas Adultas Mayores
# Convención sobre los Derechos del Niño
# Corte Interamericana de Derechos Humanos
# Corte Suprema de Justicia de la Nación
# Cámara
# Código Civil
# Código Civil y Comercial
# Código Civil y Comercial (CCC)
# Código Civil y Comercial de la Nación
# Código Procesal Civil y Comercial
# Código Procesal Civil y Comercial (CPCC)
# Código Procesal Civil y Comercial de Entre Ríos
# Código Procesal Civil y Comercial de Entre Ríos (CPCCER)
# Código de forma
# Código de rito
# DL 5.963
# Decreto reglamentario 958/79 y modificatorios
# Expte. Nº 4140
# Expte. Nº 4142
# Expte. Nº 4247
# Expte. Nº 6381
# Expte. Nº 8713
# Fallos
# Guía de Buenas Prácticas
# L.A.S.
# L.C.Q.
# L.F.
# L.F. N° 10889
# LA
# LCQ
# LEY 23737
# LEY DE DEFENSA CONSUMIDOR
# LF nro. 11843 S/ INCIDENTE COMPETENCIA
# LOPJ
# LPF
# LS
# Ley 10.636
# Ley 10.855
# Ley 10025
# Ley 10668
# Ley 11.151
# Ley 14.159
# Ley 24.449
# Ley 24.522
# Ley 24449
# Ley 26.485
# Ley 26.487
# Ley 26061
# Ley 27.440
# Ley 27423
# Ley 48
# Ley 4878
# Ley 5796
# Ley 7046
# Ley 9776
# Ley Arancelaria
# Ley Nacional de Tránsito (LNT)
# Ley Nacional de Tránsito Nro. 24.449
# Ley Nº 9234
# Ley Orgánica de las cuestiones de competencia
# Ley Orgánica del Poder Judicial (LOPJ)
# Ley Orgánica del Poder Judicial - Ley 6902
# Ley Procesal de Familia
# Ley Procesal de Familia (Ley Provincial 10.668)
# Ley Prov. 9.861
# Ley de Protección Integral de los Derechos de las Niñas, Niños y Adolescentes (Ley Nacional 26.061)
# Ley de Protección Integral de los Derechos del Niño, el Adolescente y la Familia (Ley Provincial 9.861)
# Ley provincial 6.351
# Ordenamiento Procesal
# Ordenanza Municipal 17376
# Pacto de San José de Costa Rica
# Procedimiento de intervención del Organismo de Protección de Derechos de la Provincia de Entre Ríos (Resolución 170/19)
# Reglamento de Presentaciones Electrónicas
# Resol. Trib. Sup. 340/2023 DGA
# URBANOTEC S.A. S/ QUIEBRA
# código civil
# código civil y comercial
# código procesal civil y comercial
# ley 10.407
# ley 10.704
# ley 10.956
# ley 19.550
# ley 25.529
# ley 26.485
# ley 26.657
# ley 48
# ley 6902
# ley 7046
# ley 7504
# ley arancelaria
# ley de aranceles
# ley de honorarios profesionales
# ordenamiento de forma local
# resolución
# sentencia
# texto según ley 10.704
# unknown
