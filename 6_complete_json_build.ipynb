# %%
import json
import os
from pathlib import Path

def build_unified_json():
    """
    Build unified JSON files by combining data from multiple sources:
    - fallos_json: Main ruling content
    - articulos_estructurados: Citations data  
    - summaries: Core summaries
    """
    
    # Define paths
    base_path = Path("datasets")
    fallos_path = base_path / "fallos_json"
    articulos_path = base_path / "articulos_estructurados"
    summaries_path = base_path / "summaries"
    output_path = base_path / "unified_json"
    
    # Create output directory
    output_path.mkdir(exist_ok=True)
    
    # Process each month folder
    for month_folder in fallos_path.iterdir():
        if not month_folder.is_dir():
            continue
            
        mes = month_folder.name
        print(f"Processing month: {mes}")
        
        # Create month output directory
        month_output_path = output_path / mes
        month_output_path.mkdir(exist_ok=True)
        
        # Process each ruling in the month
        for fallo_file in month_folder.glob("*.json"):
            id_fallo = fallo_file.stem  # filename without extension
            
            try:
                # Load main ruling data
                with open(fallo_file, 'r', encoding='utf-8') as f:
                    fallo_data = json.load(f)
                
                # Handle case where fallo_data is a list instead of dict
                if isinstance(fallo_data, list):
                    print(f"  ! Warning: {id_fallo} contains a list, taking first element")
                    fallo_data = fallo_data[0] if fallo_data else {}
                
                # Load citations data
                articulos_file = articulos_path / mes / f"{id_fallo}.json"
                articulos_citados = {}
                if articulos_file.exists():
                    with open(articulos_file, 'r', encoding='utf-8') as f:
                        articulos_data = json.load(f)
                        # Handle list case for articulos too
                        if isinstance(articulos_data, list):
                            articulos_data = articulos_data[0] if articulos_data else {}
                        articulos_citados = articulos_data.get("RULING_CITATIONS", {})
                
                # Load summary data
                summary_file = summaries_path / mes / f"{id_fallo}.json"
                idea_central = ""
                if summary_file.exists():
                    with open(summary_file, 'r', encoding='utf-8') as f:
                        summary_data = json.load(f)
                        # Handle list case for summaries too
                        if isinstance(summary_data, list):
                            summary_data = summary_data[0] if summary_data else {}
                        idea_central = summary_data.get("CORE_SUMMARY", "")
                
                # Build unified structure
                unified_json = {
                    "METADATOS": {
                        "ID_FALLO": id_fallo,
                        "MES": mes,
                        "ARTICULOS_CITADOS": articulos_citados
                    },
                    "MATERIA_PRELIMINAR": fallo_data.get("INFORMACION", {}).get("MATERIA_PRELIMINAR", ""),
                    "IDEA_CENTRAL": idea_central,
                    "CONTENIDO": fallo_data.get("CONTENIDO", {})
                }
                
                # Save unified JSON
                output_file = month_output_path / f"{id_fallo}.json"
                with open(output_file, 'w', encoding='utf-8') as f:
                    json.dump(unified_json, f, ensure_ascii=False, indent=2)
                
                print(f"  ✓ Created unified JSON for {id_fallo}")
                
            except Exception as e:
                print(f"  ✗ Error processing {id_fallo}: {str(e)}")
    
    print("Unified JSON generation completed!")

# Run the function
build_unified_json()
# Out:
# Processing month: 03
#   ! Warning: 8985 contains a list, taking first element
#   ✓ Created unified JSON for 8985
#   ! Warning: 8946 contains a list, taking first element
#   ✓ Created unified JSON for 8946
#   ! Warning: 9029 contains a list, taking first element
#   ✓ Created unified JSON for 9029
#   ! Warning: 9025 contains a list, taking first element
#   ✓ Created unified JSON for 9025
#   ! Warning: 9024 contains a list, taking first element
#   ✓ Created unified JSON for 9024
#   ! Warning: 9032 contains a list, taking first element
#   ✓ Created unified JSON for 9032
#   ! Warning: 8947 contains a list, taking first element
#   ✓ Created unified JSON for 8947
#   ! Warning: 8984 contains a list, taking first element
#   ✓ Created unified JSON for 8984
#   ! Warning: 9019 contains a list, taking first element
#   ✓ Created unified JSON for 9019
#   ! Warning: 9035 contains a list, taking first element
#   ✓ Created unified JSON for 9035
#   ! Warning: 9023 contains a list, taking first element
#   ✓ Created unified JSON for 9023
#   ! Warning: 8887 contains a list, taking first element
#   ✓ Created unified JSON for 8887
#   ! Warning: 8940 contains a list, taking first element
#   ✓ Created unified JSON for 8940
#   ! Warning: 8852 contains a list, taking first element
#   ✓ Created unified JSON for 8852
#   ! Warning: 8916 contains a list, taking first element
#   ✓ Created unified JSON for 8916
#   ! Warning: 8613 contains a list, taking first element
#   ✓ Created unified JSON for 8613
#   ! Warning: 8903 contains a list, taking first element
#   ✓ Created unified JSON for 8903
#   ! Warning: 8939 contains a list, taking first element
#   ✓ Created unified JSON for 8939
#   ! Warning: 8997 contains a list, taking first element
#   ✓ Created unified JSON for 8997
#   ! Warning: 8996 contains a list, taking first element
#   ✓ Created unified JSON for 8996
#   ! Warning: 9020 contains a list, taking first element
#   ✓ Created unified JSON for 9020
#   ! Warning: 8959 contains a list, taking first element
#   ✓ Created unified JSON for 8959
#   ! Warning: 8840 contains a list, taking first element
#   ✓ Created unified JSON for 8840
#   ! Warning: 9031 contains a list, taking first element
#   ✓ Created unified JSON for 9031
#   ! Warning: 8973 contains a list, taking first element
#   ✓ Created unified JSON for 8973
#   ! Warning: 8932 contains a list, taking first element
#   ✓ Created unified JSON for 8932
#   ! Warning: 8949 contains a list, taking first element
#   ✓ Created unified JSON for 8949
#   ! Warning: 9030 contains a list, taking first element
#   ✓ Created unified JSON for 9030
#   ! Warning: 9026 contains a list, taking first element
#   ✓ Created unified JSON for 9026
#   ! Warning: 8953 contains a list, taking first element
#   ✓ Created unified JSON for 8953
# Processing month: 04
#   ! Warning: 8771 contains a list, taking first element
#   ✓ Created unified JSON for 8771
#   ! Warning: 9004 contains a list, taking first element
#   ✓ Created unified JSON for 9004
#   ! Warning: 8995 contains a list, taking first element
#   ✓ Created unified JSON for 8995
#   ! Warning: 9056 contains a list, taking first element
#   ✓ Created unified JSON for 9056
#   ! Warning: 9001 contains a list, taking first element
#   ✓ Created unified JSON for 9001
#   ! Warning: 9061 contains a list, taking first element
#   ✓ Created unified JSON for 9061
#   ! Warning: 8765 contains a list, taking first element
#   ✓ Created unified JSON for 8765
#   ! Warning: 8965 contains a list, taking first element
#   ✓ Created unified JSON for 8965
#   ! Warning: 9006 contains a list, taking first element
#   ✓ Created unified JSON for 9006
# Processing month: 05
#   ! Warning: 8878 contains a list, taking first element
#   ✓ Created unified JSON for 8878
#   ! Warning: 9013 contains a list, taking first element
#   ✓ Created unified JSON for 9013
#   ! Warning: 9033 contains a list, taking first element
#   ✓ Created unified JSON for 9033
#   ! Warning: 8967 contains a list, taking first element
#   ✓ Created unified JSON for 8967
#   ! Warning: 9028 contains a list, taking first element
#   ✓ Created unified JSON for 9028
#   ! Warning: 8999 contains a list, taking first element
#   ✓ Created unified JSON for 8999
#   ! Warning: 8848 contains a list, taking first element
#   ✓ Created unified JSON for 8848
#   ! Warning: 8956 contains a list, taking first element
#   ✓ Created unified JSON for 8956
#   ! Warning: 9038 contains a list, taking first element
#   ✓ Created unified JSON for 9038
#   ! Warning: 9014 contains a list, taking first element
#   ✓ Created unified JSON for 9014
#   ! Warning: 9022 contains a list, taking first element
#   ✓ Created unified JSON for 9022
#   ! Warning: 9034 contains a list, taking first element
#   ✓ Created unified JSON for 9034
#   ! Warning: 8936 contains a list, taking first element
#   ✓ Created unified JSON for 8936
#   ! Warning: 8977 contains a list, taking first element
#   ✓ Created unified JSON for 8977
#   ! Warning: 9021 contains a list, taking first element
#   ✓ Created unified JSON for 9021
#   ! Warning: 8974 contains a list, taking first element
#   ✓ Created unified JSON for 8974
#   ! Warning: 9017 contains a list, taking first element
#   ✓ Created unified JSON for 9017
#   ! Warning: 9001 contains a list, taking first element
#   ✓ Created unified JSON for 9001
#   ! Warning: 8980 contains a list, taking first element
#   ✓ Created unified JSON for 8980
#   ! Warning: 9041 contains a list, taking first element
#   ✓ Created unified JSON for 9041
#   ! Warning: 8914 contains a list, taking first element
#   ✓ Created unified JSON for 8914
#   ! Warning: 8518 contains a list, taking first element
#   ✓ Created unified JSON for 8518
#   ! Warning: 8689 contains a list, taking first element
#   ✓ Created unified JSON for 8689
#   ! Warning: 9011 contains a list, taking first element
#   ✓ Created unified JSON for 9011
#   ! Warning: 8991 contains a list, taking first element
#   ✓ Created unified JSON for 8991
#   ! Warning: 8909 contains a list, taking first element
#   ✓ Created unified JSON for 8909
#   ! Warning: 9027 contains a list, taking first element
#   ✓ Created unified JSON for 9027
#   ! Warning: 8362 contains a list, taking first element
#   ✓ Created unified JSON for 8362
#   ! Warning: 8861 contains a list, taking first element
#   ✓ Created unified JSON for 8861
#   ! Warning: 8359 contains a list, taking first element
#   ✓ Created unified JSON for 8359
#   ! Warning: 8836 contains a list, taking first element
#   ✓ Created unified JSON for 8836
#   ! Warning: 8986 contains a list, taking first element
#   ✓ Created unified JSON for 8986
#   ! Warning: 8713 contains a list, taking first element
#   ✓ Created unified JSON for 8713
#   ! Warning: 9010 contains a list, taking first element
#   ✓ Created unified JSON for 9010
# Processing month: 02
#   ! Warning: 8927 contains a list, taking first element
#   ✓ Created unified JSON for 8927
#   ! Warning: 8971 contains a list, taking first element
#   ✓ Created unified JSON for 8971
#   ! Warning: 8926 contains a list, taking first element
#   ✓ Created unified JSON for 8926
#   ! Warning: 8865 contains a list, taking first element
#   ✓ Created unified JSON for 8865
#   ! Warning: 8104 contains a list, taking first element
#   ✓ Created unified JSON for 8104
#   ! Warning: 8344 contains a list, taking first element
#   ✓ Created unified JSON for 8344
#   ! Warning: 8948 contains a list, taking first element
#   ✓ Created unified JSON for 8948
#   ! Warning: 8752 contains a list, taking first element
#   ✓ Created unified JSON for 8752
#   ! Warning: 8569 contains a list, taking first element
#   ✓ Created unified JSON for 8569
#   ! Warning: 8142 contains a list, taking first element
#   ✓ Created unified JSON for 8142
# Processing month: 11
#   ! Warning: 8792 contains a list, taking first element
#   ✓ Created unified JSON for 8792
#   ! Warning: 9064 contains a list, taking first element
#   ✓ Created unified JSON for 9064
#   ! Warning: 9160 contains a list, taking first element
#   ✓ Created unified JSON for 9160
#   ! Warning: 9161 contains a list, taking first element
#   ✓ Created unified JSON for 9161
#   ! Warning: 9065 contains a list, taking first element
#   ✓ Created unified JSON for 9065
#   ! Warning: 8678 contains a list, taking first element
#   ✓ Created unified JSON for 8678
#   ! Warning: 9012 contains a list, taking first element
#   ✓ Created unified JSON for 9012
#   ! Warning: 9116 contains a list, taking first element
#   ✓ Created unified JSON for 9116
#   ! Warning: 9079 contains a list, taking first element
#   ✓ Created unified JSON for 9079
#   ! Warning: 9075 contains a list, taking first element
#   ✓ Created unified JSON for 9075
#   ! Warning: 8131 contains a list, taking first element
#   ✓ Created unified JSON for 8131
#   ! Warning: 9164 contains a list, taking first element
#   ✓ Created unified JSON for 9164
#   ! Warning: 9172 contains a list, taking first element
#   ✓ Created unified JSON for 9172
#   ! Warning: 9060 contains a list, taking first element
#   ✓ Created unified JSON for 9060
#   ! Warning: 8935 contains a list, taking first element
#   ✓ Created unified JSON for 8935
#   ! Warning: 9109 contains a list, taking first element
#   ✓ Created unified JSON for 9109
#   ! Warning: 9129 contains a list, taking first element
#   ✓ Created unified JSON for 9129
#   ! Warning: 9144 contains a list, taking first element
#   ✓ Created unified JSON for 9144
#   ! Warning: 9153 contains a list, taking first element
#   ✓ Created unified JSON for 9153
#   ! Warning: 9169 contains a list, taking first element
#   ✓ Created unified JSON for 9169
#   ! Warning: 9165 contains a list, taking first element
#   ✓ Created unified JSON for 9165
#   ! Warning: 8518 contains a list, taking first element
#   ✓ Created unified JSON for 8518
#   ! Warning: 9077 contains a list, taking first element
#   ✓ Created unified JSON for 9077
#   ! Warning: 9139 contains a list, taking first element
#   ✓ Created unified JSON for 9139
#   ! Warning: 9070 contains a list, taking first element
#   ✓ Created unified JSON for 9070
#   ! Warning: 7351 contains a list, taking first element
#   ✓ Created unified JSON for 7351
#   ! Warning: 9158 contains a list, taking first element
#   ✓ Created unified JSON for 9158
#   ! Warning: 9119 contains a list, taking first element
#   ✓ Created unified JSON for 9119
#   ! Warning: 8973 contains a list, taking first element
#   ✓ Created unified JSON for 8973
#   ! Warning: 9114 contains a list, taking first element
#   ✓ Created unified JSON for 9114
# Processing month: 10
#   ! Warning: 9140 contains a list, taking first element
#   ✓ Created unified JSON for 9140
#   ! Warning: 9117 contains a list, taking first element
#   ✓ Created unified JSON for 9117
#   ! Warning: 9101 contains a list, taking first element
#   ✓ Created unified JSON for 9101
#   ! Warning: 9121 contains a list, taking first element
#   ✓ Created unified JSON for 9121
#   ! Warning: 9072 contains a list, taking first element
#   ✓ Created unified JSON for 9072
#   ! Warning: 9137 contains a list, taking first element
#   ✓ Created unified JSON for 9137
#   ! Warning: 9120 contains a list, taking first element
#   ✓ Created unified JSON for 9120
#   ! Warning: 9127 contains a list, taking first element
#   ✓ Created unified JSON for 9127
#   ! Warning: 9111 contains a list, taking first element
#   ✓ Created unified JSON for 9111
#   ! Warning: 9150 contains a list, taking first element
#   ✓ Created unified JSON for 9150
#   ! Warning: 8628 contains a list, taking first element
#   ✓ Created unified JSON for 8628
#   ! Warning: 9096 contains a list, taking first element
#   ✓ Created unified JSON for 9096
#   ! Warning: 8500 contains a list, taking first element
#   ✓ Created unified JSON for 8500
#   ! Warning: 8941 contains a list, taking first element
#   ✓ Created unified JSON for 8941
#   ! Warning: 9106 contains a list, taking first element
#   ✓ Created unified JSON for 9106
#   ! Warning: 9110 contains a list, taking first element
#   ✓ Created unified JSON for 9110
#   ! Warning: 9075 contains a list, taking first element
#   ✓ Created unified JSON for 9075
#   ! Warning: 9130 contains a list, taking first element
#   ✓ Created unified JSON for 9130
#   ! Warning: 9126 contains a list, taking first element
#   ✓ Created unified JSON for 9126
#   ! Warning: 8961 contains a list, taking first element
#   ✓ Created unified JSON for 8961
#   ! Warning: 9125 contains a list, taking first element
#   ✓ Created unified JSON for 9125
#   ! Warning: 8962 contains a list, taking first element
#   ✓ Created unified JSON for 8962
#   ! Warning: 9109 contains a list, taking first element
#   ✓ Created unified JSON for 9109
#   ! Warning: 9152 contains a list, taking first element
#   ✓ Created unified JSON for 9152
#   ! Warning: 9105 contains a list, taking first element
#   ✓ Created unified JSON for 9105
#   ! Warning: 9113 contains a list, taking first element
#   ✓ Created unified JSON for 9113
#   ! Warning: 9057 contains a list, taking first element
#   ✓ Created unified JSON for 9057
#   ! Warning: 8980 contains a list, taking first element
#   ✓ Created unified JSON for 8980
#   ! Warning: 9128 contains a list, taking first element
#   ✓ Created unified JSON for 9128
#   ! Warning: 8543 contains a list, taking first element
#   ✓ Created unified JSON for 8543
#   ! Warning: 9149 contains a list, taking first element
#   ✓ Created unified JSON for 9149
#   ! Warning: 9124 contains a list, taking first element
#   ✓ Created unified JSON for 9124
#   ! Warning: 9132 contains a list, taking first element
#   ✓ Created unified JSON for 9132
#   ✗ Error processing 9093: Expecting value: line 73 column 5 (char 16919)
#   ! Warning: 9142 contains a list, taking first element
#   ✓ Created unified JSON for 9142
#   ! Warning: 7351 contains a list, taking first element
#   ✓ Created unified JSON for 7351
#   ! Warning: 9089 contains a list, taking first element
#   ✓ Created unified JSON for 9089
#   ! Warning: 9123 contains a list, taking first element
#   ✓ Created unified JSON for 9123
#   ! Warning: 9134 contains a list, taking first element
#   ✓ Created unified JSON for 9134
#   ! Warning: 8729 contains a list, taking first element
#   ✓ Created unified JSON for 8729
# Processing month: 07
#   ! Warning: 9005 contains a list, taking first element
#   ✓ Created unified JSON for 9005
#   ! Warning: 9009 contains a list, taking first element
#   ✓ Created unified JSON for 9009
#   ! Warning: 9048 contains a list, taking first element
#   ✓ Created unified JSON for 9048
#   ! Warning: 9008 contains a list, taking first element
#   ✓ Created unified JSON for 9008
#   ! Warning: 8992 contains a list, taking first element
#   ✓ Created unified JSON for 8992
#   ! Warning: 9074 contains a list, taking first element
#   ✓ Created unified JSON for 9074
#   ! Warning: 8941 contains a list, taking first element
#   ✓ Created unified JSON for 8941
#   ! Warning: 9076 contains a list, taking first element
#   ✓ Created unified JSON for 9076
#   ! Warning: 8554 contains a list, taking first element
#   ✓ Created unified JSON for 8554
#   ! Warning: 9088 contains a list, taking first element
#   ✓ Created unified JSON for 9088
#   ! Warning: 9071 contains a list, taking first element
#   ✓ Created unified JSON for 9071
#   ! Warning: 9084 contains a list, taking first element
#   ✓ Created unified JSON for 9084
# Processing month: 09
#   ! Warning: 8439 contains a list, taking first element
#   ✓ Created unified JSON for 8439
#   ! Warning: 9100 contains a list, taking first element
#   ✓ Created unified JSON for 9100
#   ! Warning: 8999 contains a list, taking first element
#   ✓ Created unified JSON for 8999
#   ! Warning: 9042 contains a list, taking first element
#   ✓ Created unified JSON for 9042
#   ! Warning: 9039 contains a list, taking first element
#   ✓ Created unified JSON for 9039
#   ! Warning: 8982 contains a list, taking first element
#   ✓ Created unified JSON for 8982
#   ! Warning: 8756 contains a list, taking first element
#   ✓ Created unified JSON for 8756
#   ! Warning: 8886 contains a list, taking first element
#   ✓ Created unified JSON for 8886
#   ! Warning: 9059 contains a list, taking first element
#   ✓ Created unified JSON for 9059
#   ! Warning: 8981 contains a list, taking first element
#   ✓ Created unified JSON for 8981
#   ! Warning: 9082 contains a list, taking first element
#   ✓ Created unified JSON for 9082
#   ! Warning: 8778 contains a list, taking first element
#   ✓ Created unified JSON for 8778
#   ! Warning: 9036 contains a list, taking first element
#   ✓ Created unified JSON for 9036
#   ! Warning: 9115 contains a list, taking first element
#   ✓ Created unified JSON for 9115
#   ! Warning: 9135 contains a list, taking first element
#   ✓ Created unified JSON for 9135
#   ! Warning: 9067 contains a list, taking first element
#   ✓ Created unified JSON for 9067
#   ! Warning: 8990 contains a list, taking first element
#   ✓ Created unified JSON for 8990
#   ! Warning: 6424 contains a list, taking first element
#   ✓ Created unified JSON for 6424
#   ! Warning: 9047 contains a list, taking first element
#   ✓ Created unified JSON for 9047
# Processing month: 08
#   ! Warning: 8993 contains a list, taking first element
#   ✓ Created unified JSON for 8993
#   ! Warning: 8439 contains a list, taking first element
#   ✓ Created unified JSON for 8439
#   ! Warning: 9068 contains a list, taking first element
#   ✓ Created unified JSON for 9068
#   ! Warning: 8926 contains a list, taking first element
#   ✓ Created unified JSON for 8926
#   ! Warning: 8951 contains a list, taking first element
#   ✓ Created unified JSON for 8951
#   ! Warning: 9045 contains a list, taking first element
#   ✓ Created unified JSON for 9045
#   ! Warning: 8642 contains a list, taking first element
#   ✓ Created unified JSON for 8642
#   ! Warning: 9062 contains a list, taking first element
#   ✓ Created unified JSON for 9062
#   ! Warning: 9107 contains a list, taking first element
#   ✓ Created unified JSON for 9107
#   ! Warning: 8487 contains a list, taking first element
#   ✓ Created unified JSON for 8487
#   ! Warning: 8956 contains a list, taking first element
#   ✓ Created unified JSON for 8956
#   ! Warning: 9078 contains a list, taking first element
#   ✓ Created unified JSON for 9078
#   ! Warning: 9096 contains a list, taking first element
#   ✓ Created unified JSON for 9096
#   ! Warning: 8691 contains a list, taking first element
#   ✓ Created unified JSON for 8691
#   ! Warning: 9063 contains a list, taking first element
#   ✓ Created unified JSON for 9063
#   ! Warning: 9099 contains a list, taking first element
#   ✓ Created unified JSON for 9099
#   ! Warning: 8558 contains a list, taking first element
#   ✓ Created unified JSON for 8558
#   ! Warning: 9095 contains a list, taking first element
#   ✓ Created unified JSON for 9095
#   ! Warning: 8954 contains a list, taking first element
#   ✓ Created unified JSON for 8954
#   ! Warning: 9083 contains a list, taking first element
#   ✓ Created unified JSON for 9083
#   ! Warning: 9040 contains a list, taking first element
#   ✓ Created unified JSON for 9040
#   ! Warning: 9112 contains a list, taking first element
#   ✓ Created unified JSON for 9112
#   ! Warning: 8778 contains a list, taking first element
#   ✓ Created unified JSON for 8778
#   ! Warning: 9094 contains a list, taking first element
#   ✓ Created unified JSON for 9094
#   ! Warning: 9108 contains a list, taking first element
#   ✓ Created unified JSON for 9108
#   ! Warning: 7751 contains a list, taking first element
#   ✓ Created unified JSON for 7751
#   ! Warning: 9077 contains a list, taking first element
#   ✓ Created unified JSON for 9077
#   ! Warning: 9085 contains a list, taking first element
#   ✓ Created unified JSON for 9085
#   ! Warning: 9046 contains a list, taking first element
#   ✓ Created unified JSON for 9046
#   ! Warning: 9103 contains a list, taking first element
#   ✓ Created unified JSON for 9103
#   ! Warning: 9007 contains a list, taking first element
#   ✓ Created unified JSON for 9007
#   ! Warning: 8677 contains a list, taking first element
#   ✓ Created unified JSON for 8677
#   ! Warning: 9118 contains a list, taking first element
#   ✓ Created unified JSON for 9118
#   ! Warning: 8748 contains a list, taking first element
#   ✓ Created unified JSON for 8748
#   ! Warning: 8791 contains a list, taking first element
#   ✓ Created unified JSON for 8791
#   ! Warning: 9092 contains a list, taking first element
#   ✓ Created unified JSON for 9092
# Processing month: 06
#   ! Warning: 9052 contains a list, taking first element
#   ✓ Created unified JSON for 9052
#   ! Warning: 9044 contains a list, taking first element
#   ✓ Created unified JSON for 9044
#   ! Warning: 9087 contains a list, taking first element
#   ✓ Created unified JSON for 9087
#   ! Warning: 9048 contains a list, taking first element
#   ✓ Created unified JSON for 9048
#   ! Warning: 8989 contains a list, taking first element
#   ✓ Created unified JSON for 8989
#   ! Warning: 9073 contains a list, taking first element
#   ✓ Created unified JSON for 9073
#   ! Warning: 8988 contains a list, taking first element
#   ✓ Created unified JSON for 8988
#   ! Warning: 9049 contains a list, taking first element
#   ✓ Created unified JSON for 9049
#   ! Warning: 8951 contains a list, taking first element
#   ✓ Created unified JSON for 8951
#   ! Warning: 9069 contains a list, taking first element
#   ✓ Created unified JSON for 9069
#   ! Warning: 9086 contains a list, taking first element
#   ✓ Created unified JSON for 9086
#   ! Warning: 9045 contains a list, taking first element
#   ✓ Created unified JSON for 9045
#   ! Warning: 9053 contains a list, taking first element
#   ✓ Created unified JSON for 9053
#   ! Warning: 9058 contains a list, taking first element
#   ✓ Created unified JSON for 9058
#   ! Warning: 9054 contains a list, taking first element
#   ✓ Created unified JSON for 9054
#   ! Warning: 9042 contains a list, taking first element
#   ✓ Created unified JSON for 9042
#   ! Warning: 9015 contains a list, taking first element
#   ✓ Created unified JSON for 9015
#   ! Warning: 9081 contains a list, taking first element
#   ✓ Created unified JSON for 9081
#   ! Warning: 8344r contains a list, taking first element
#   ✓ Created unified JSON for 8344r
#   ! Warning: 9079 contains a list, taking first element
#   ✓ Created unified JSON for 9079
#   ! Warning: 9080 contains a list, taking first element
#   ✓ Created unified JSON for 9080
#   ! Warning: 8941 contains a list, taking first element
#   ✓ Created unified JSON for 8941
#   ! Warning: 9014 contains a list, taking first element
#   ✓ Created unified JSON for 9014
#   ! Warning: 9043 contains a list, taking first element
#   ✓ Created unified JSON for 9043
#   ! Warning: 9055 contains a list, taking first element
#   ✓ Created unified JSON for 9055
#   ! Warning: 9002 contains a list, taking first element
#   ✓ Created unified JSON for 9002
#   ! Warning: 9018 contains a list, taking first element
#   ✓ Created unified JSON for 9018
#   ! Warning: 8998 contains a list, taking first element
#   ✓ Created unified JSON for 8998
#   ! Warning: 8958 contains a list, taking first element
#   ✓ Created unified JSON for 8958
#   ! Warning: 8344 contains a list, taking first element
#   ✓ Created unified JSON for 8344
#   ! Warning: 8981 contains a list, taking first element
#   ✓ Created unified JSON for 8981
#   ! Warning: 8978 contains a list, taking first element
#   ✓ Created unified JSON for 8978
#   ! Warning: 8851 contains a list, taking first element
#   ✓ Created unified JSON for 8851
#   ! Warning: 9098 contains a list, taking first element
#   ✓ Created unified JSON for 9098
#   ! Warning: 9011 contains a list, taking first element
#   ✓ Created unified JSON for 9011
#   ! Warning: 8987 contains a list, taking first element
#   ✓ Created unified JSON for 8987
#   ! Warning: 9050 contains a list, taking first element
#   ✓ Created unified JSON for 9050
#   ! Warning: 9070 contains a list, taking first element
#   ✓ Created unified JSON for 9070
#   ! Warning: 8765 contains a list, taking first element
#   ✓ Created unified JSON for 8765
#   ! Warning: 8620 contains a list, taking first element
#   ✓ Created unified JSON for 8620
#   ! Warning: 9066 contains a list, taking first element
#   ✓ Created unified JSON for 9066
#   ! Warning: 8925 contains a list, taking first element
#   ✓ Created unified JSON for 8925
#   ! Warning: 9051 contains a list, taking first element
#   ✓ Created unified JSON for 9051
#   ! Warning: 9047 contains a list, taking first element
#   ✓ Created unified JSON for 9047
#   ! Warning: 9010 contains a list, taking first element
#   ✓ Created unified JSON for 9010
# Processing month: 12
#   ! Warning: 9136 contains a list, taking first element
#   ✓ Created unified JSON for 9136
#   ! Warning: 9194 contains a list, taking first element
#   ✓ Created unified JSON for 9194
#   ! Warning: 9116 contains a list, taking first element
#   ✓ Created unified JSON for 9116
#   ! Warning: 9141 contains a list, taking first element
#   ✓ Created unified JSON for 9141
#   ! Warning: 9146 contains a list, taking first element
#   ✓ Created unified JSON for 9146
#   ! Warning: 8983 contains a list, taking first element
#   ✓ Created unified JSON for 8983
#   ! Warning: 9096 contains a list, taking first element
#   ✓ Created unified JSON for 9096
#   ! Warning: 9192 contains a list, taking first element
#   ✓ Created unified JSON for 9192
#   ! Warning: 9171 contains a list, taking first element
#   ✓ Created unified JSON for 9171
#   ! Warning: 9018 contains a list, taking first element
#   ✓ Created unified JSON for 9018
#   ! Warning: 8977 contains a list, taking first element
#   ✓ Created unified JSON for 8977
#   ! Warning: 9076 contains a list, taking first element
#   ✓ Created unified JSON for 9076
#   ! Warning: 8630 contains a list, taking first element
#   ✓ Created unified JSON for 8630
#   ! Warning: 8935 contains a list, taking first element
#   ✓ Created unified JSON for 8935
#   ! Warning: 9083 contains a list, taking first element
#   ✓ Created unified JSON for 9083
#   ! Warning: 9016 contains a list, taking first element
#   ✓ Created unified JSON for 9016
#   ! Warning: 9128 contains a list, taking first element
#   ✓ Created unified JSON for 9128
#   ! Warning: 9190 contains a list, taking first element
#   ✓ Created unified JSON for 9190
#   ! Warning: 9094 contains a list, taking first element
#   ✓ Created unified JSON for 9094
#   ! Warning: 9173 contains a list, taking first element
#   ✓ Created unified JSON for 9173
#   ! Warning: 9098 contains a list, taking first element
#   ✓ Created unified JSON for 9098
#   ! Warning: 8544 contains a list, taking first element
#   ✓ Created unified JSON for 8544
#   ! Warning: 9162 contains a list, taking first element
#   ✓ Created unified JSON for 9162
#   ! Warning: 5a27ca53-26c2-44cb-8711-7035f3bc622e contains a list, taking first element
#   ✓ Created unified JSON for 5a27ca53-26c2-44cb-8711-7035f3bc622e
#   ! Warning: 9175 contains a list, taking first element
#   ✓ Created unified JSON for 9175
#   ! Warning: 6424 contains a list, taking first element
#   ✓ Created unified JSON for 6424
#   ! Warning: 8206 contains a list, taking first element
#   ✓ Created unified JSON for 8206
#   ! Warning: 9155 contains a list, taking first element
#   ✓ Created unified JSON for 9155
#   ! Warning: 9084 contains a list, taking first element
#   ✓ Created unified JSON for 9084
#   ! Warning: 9180 contains a list, taking first element
#   ✓ Created unified JSON for 9180
#   ! Warning: 9211 contains a list, taking first element
#   ✓ Created unified JSON for 9211
# Unified JSON generation completed!
