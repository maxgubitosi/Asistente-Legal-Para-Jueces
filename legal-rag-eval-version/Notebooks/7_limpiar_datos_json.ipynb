# %%
import os
from collections import Counter, defaultdict
import json
import re
from pathlib import Path

# %%
def create_json_stats(base_dir: str="../datasets/fallos_json", output_stats: str="main_source_cited_articles_stats.json"):
    # Diccionario para almacenar la información
    result = {}

    # Recorrer todas las carpetas y archivos .json
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".json"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, "r", encoding="utf-8") as f:
                        data = json.load(f)
                    citations = (
                        data.get("METADATOS", {})
                        .get("ARTICULOS_CITADOS", {})
                        .get("citations", [])
                    )
                    for citation in citations:
                        main_source = citation.get("main_source")
                        cited_articles = citation.get("cited_articles", [])
                        if main_source is not None and cited_articles is not None:
                            if main_source not in result:
                                result[main_source] = []
                            result[main_source].extend(cited_articles)
                except Exception as e:
                    print(f"Error en {file_path}: {e}")

    # Construir el JSON de salida
    output = {}
    for source, articles in result.items():
        freq = Counter(articles)
        output[source] = {
            "cited_articles_frequency": dict(freq),
            "total_cited_articles": sum(freq.values())
        }

    # Guardar el resultado en un archivo
    with open(output_stats, "w", encoding="utf-8") as f:
        json.dump(output, f, ensure_ascii=False, indent=2)

    print(f"Archivo '{output_stats}' generado correctamente.")

# %%
def print_json_stats_summary(json_path="main_source_cited_articles_stats.json"):
    # Abrir el archivo generado
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Crear un diccionario con main_source y su frecuencia total
    total_freq = {k: v["total_cited_articles"] for k, v in data.items()}

    # Mostrar el resultado como JSON puro
    print(json.dumps(total_freq, ensure_ascii=False, indent=2))

# %%
def cleanner(json_path):
    """
    Limpia el campo IDEA_CENTRAL eliminando encabezados redundantes
    
    Args:
        json_path (str): Ruta al archivo JSON a procesar
    """
    # Leer el archivo JSON
    with open(json_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    # Verificar si existe el campo IDEA_CENTRAL
    if "IDEA_CENTRAL" in data:
        idea_central = data["IDEA_CENTRAL"]
        
        # Patrones a eliminar (con variaciones)
        patterns_to_remove = [
            r"^\*\*IDEA CENTRAL DEL FALLO\*\*\n\n",
            r"^### IDEA CENTRAL DEL FALLO\n\n",
            r"^\*\*IDEA CENTRAL DEL FALLO:\*\*\n\n",
            r"^### IDEA CENTRAL DEL FALLO:\n\n",
            r"^\*\*IDEA CENTRAL:\*\*\n\n",
            r"^### IDEA CENTRAL:\n\n",
            r"^\*\*IDEA CENTRAL DEL FALLO\*\*\n",
            r"^### IDEA CENTRAL DEL FALLO\n",
            # Nuevos patrones corregidos
            r"^\*\*IDEA CENTRAL DEL FALLO JUDICIAL\*\*\n\n",
            r"^\*\*IDEA CENTRAL DEL FALLO JUDICIAL\*\*\n",
            r"^\*\*Decisión Judicial Principal:\*\*\n\n",
            r"^\*\*Decisión Judicial Principal:\*\*\n",
            r"^\*\*Decisión Judicial Principal:\*\*",
            r"^\*\*decisión judicial principal:\*\*\n",
            # Patrones con espacios al inicio
            r"^\s+\*\*IDEA CENTRAL DEL FALLO\*\*\n\n",
            r"^\s+### IDEA CENTRAL DEL FALLO\n\n",
            r"^\s+\*\*IDEA CENTRAL DEL FALLO JUDICIAL\*\*\n\n",
            r"^\s+\*\*Decisión Judicial Principal:\*\*\n\n",
            r"^\s+\*\*Decisión Judicial Principal:\*\*\n",
            r"^\s+\*\*Decisión Judicial Principal:\*\*",
            r"^\s+\*\*decisión judicial principal:\*\*",
        ]
        
        # Aplicar cada patrón
        cleaned_text = idea_central
        for pattern in patterns_to_remove:
            cleaned_text = re.sub(pattern, "", cleaned_text, flags=re.MULTILINE)
        
        # Actualizar el JSON solo si hubo cambios
        if cleaned_text != idea_central:
            data["IDEA_CENTRAL"] = cleaned_text
            print(f"✓ Limpiado encabezado en: {json_path}")
            
            # Guardar el archivo modificado
            with open(json_path, 'w', encoding='utf-8') as file:
                json.dump(data, file, ensure_ascii=False, indent=2)
            return True
        else:
            return False
    else:
        print(f"⚠ No se encontró campo IDEA_CENTRAL en: {json_path}")
        return False

def clean_idea_central(base_dir="../datasets/fallos_json"):
    # Directorio base
    base_dir = Path(base_dir)
    
    # Verificar que el directorio existe
    if not base_dir.exists():
        print(f"❌ El directorio no existe: {base_dir}")
        return
    
    # Buscar todos los archivos JSON recursivamente
    json_files = list(base_dir.rglob("*.json"))
    
    if not json_files:
        print(f"❌ No se encontraron archivos JSON en: {base_dir}")
        return
    
    print(f"📁 Encontrados {len(json_files)} archivos JSON")
    print("🚀 Iniciando procesamiento...\n")
    
    # Contadores y listas
    processed = 0
    modified = 0
    errors = 0
    not_modified = []
    
    # Procesar cada archivo
    for json_file in json_files:
        try:
            if cleanner(json_file):
                modified += 1
            else:
                not_modified.append(json_file)
            processed += 1
        except Exception as e:
            print(f"❌ Error procesando {json_file}: {e}")
            errors += 1
    
    # Resumen final
    print(f"\n📊 RESUMEN:")
    print(f"   Archivos procesados: {processed}")
    print(f"   Archivos modificados: {modified}")
    print(f"   Archivos sin modificar: {len(not_modified)}")
    print(f"   Errores: {errors}")
    
    if not_modified:
        print(f"\n📋 ARCHIVOS SIN MODIFICAR:")
        for file in not_modified:
            print(f"   - {file}")
    
    print(f"\n🎉 Proceso completado!")

# %%
def normalizar_json(base_dir="../datasets/fallos_json", output_base_dir="../datasets/fallos_json_modificados"):
    # Artículos a mover de 'Otro' a cada ley
    articulos_ley_7046 = {28, 29, 114}
    articulos_ley_10704 = {33}

    # Recorrer todas las carpetas y archivos .json
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".json"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, "r", encoding="utf-8") as f:
                        data = json.load(f)
                    citations = (
                        data.get("METADATOS", {})
                        .get("ARTICULOS_CITADOS", {})
                        .get("citations", [])
                    )
                    # Agrupar main_source únicos y eliminar duplicados
                    grouped = defaultdict(lambda: {"cited_articles": set(), "extra": set()})
                    for citation in citations:
                        main_source = citation.get("main_source")
                        cited_articles = citation.get("cited_articles")
                        extra = citation.get("extra")
                        if extra is None and "extras" in citation:
                            extra = citation.get("extras")
                        if cited_articles is None:
                            cited_articles = []
                        if extra is None:
                            extra = []
                        if isinstance(extra, str):
                            extra = [extra]
                        if main_source is not None:
                            grouped[main_source]["cited_articles"].update(cited_articles)
                            grouped[main_source]["extra"].update(extra)
                    # --- MODIFICACIÓN: Mover artículos de 'Otro' a las leyes correspondientes ---
                    otros = grouped.get("Otro")
                    if otros:
                        articulos_otro = otros["cited_articles"]
                        # Ley 7046
                        articulos_mover_7046 = articulos_otro & articulos_ley_7046
                        if articulos_mover_7046:
                            if "Ley 7046" not in grouped:
                                grouped["Ley 7046"] = {"cited_articles": set(), "extra": set()}
                            grouped["Ley 7046"]["cited_articles"].update(articulos_mover_7046)
                            articulos_otro.difference_update(articulos_mover_7046)
                        # Ley 10.704
                        articulos_mover_10704 = articulos_otro & articulos_ley_10704
                        if articulos_mover_10704:
                            if "Ley 10.704" not in grouped:
                                grouped["Ley 10.704"] = {"cited_articles": set(), "extra": set()}
                            grouped["Ley 10.704"]["cited_articles"].update(articulos_mover_10704)
                            articulos_otro.difference_update(articulos_mover_10704)
                    # Eliminar 'Otro' si queda vacío
                    if "Otro" in grouped and not grouped["Otro"]["cited_articles"]:
                        del grouped["Otro"]
                    # Reconstruir la lista de citas agrupadas y sin duplicados
                    new_citations = []
                    for main_source, vals in grouped.items():
                        new_citations.append({
                            "main_source": main_source,
                            "cited_articles": sorted(list(vals["cited_articles"])),
                            "extra": list(vals["extra"])
                        })
                    # Guardar los cambios en la nueva carpeta, replicando la estructura
                    if "METADATOS" in data and "ARTICULOS_CITADOS" in data["METADATOS"]:
                        data["METADATOS"]["ARTICULOS_CITADOS"]["citations"] = new_citations
                        # Construir ruta de salida
                        rel_path = os.path.relpath(file_path, base_dir)
                        output_path = os.path.join(output_base_dir, rel_path)
                        os.makedirs(os.path.dirname(output_path), exist_ok=True)
                        with open(output_path, "w", encoding="utf-8") as f:
                            json.dump(data, f, ensure_ascii=False, indent=2)
                except Exception as e:
                    print(f"Error en {file_path}: {e}")

    print("Archivos .json modificados guardados en la carpeta 'fallos_json_modificados', replicando la estructura original.")

# %%
base_dir = "../datasets/fallos_json"
output_stats = "main_source_cited_articles_stats.json"

create_json_stats(base_dir, output_stats)
# Out:
# Archivo 'main_source_cited_articles_stats.json' generado correctamente.

# %%
print_json_stats_summary(output_stats)
# Out:
# {
#   "Ley 7046": 641,
#   "Acuerdo General 15/18 SNE": 505,
#   "Otro": 437,
#   "Código Civil y Comercial (CCC)": 449,
#   "Ley 19.550": 3,
#   "Código Procesal Civil y Comercial (CPCC)": 790,
#   "Acuerdo General 11/20": 32,
#   "Ley 24.449": 58,
#   "Corte Suprema de Justicia de la Nación (CSJN)": 74,
#   "Constitución Nacional (CN)": 151,
#   "Ley 10.636": 1,
#   "Ley 5796": 2,
#   "Código Procesal Civil y Comercial de Entre Ríos (CPCCER)": 15,
#   "Ley 48": 16,
#   "Acordada 4/2007": 47,
#   "Ley 25.529": 6,
#   "Ley 4878": 8,
#   "Ley 27.423": 2,
#   "Ley 9776": 1,
#   "Código Procesal Penal (CPP)": 23,
#   "Ley 23.737": 7,
#   "Acuerdo General 28/20": 1,
#   "Ley 6902": 4,
#   "Constitución Provincial de Entre Ríos": 25,
#   "Ley 10.704": 84,
#   "Reglamento de Presentaciones Electrónicas": 6,
#   "Ley 10.668": 2,
#   "Ley 26.485": 6,
#   "Ley 10.855": 2,
#   "Ley 9861": 5,
#   "Ley 26.061": 11,
#   "Resolución 170/19": 6,
#   "Ley 24.522 (LCQ - Ley de Concursos y Quiebras)": 28,
#   "Convención Americana de Derechos Humanos (Pacto de San José de Costa Rica)": 13,
#   "Convención sobre los Derechos de las Personas Adultas Mayores": 4,
#   "Ley 14.159": 1,
#   "Ley 26.487": 1,
#   "Convención sobre los Derechos del Niño": 3,
#   "Guía de Buenas Prácticas": 2,
#   "Corte Interamericana de Derechos Humanos": 6,
#   "Ley 10.956": 2,
#   "Ley 10.407": 1,
#   "Resolución Tribunal Superior 340/2023 DGA": 1,
#   "Acuerdo General 28/15": 7,
#   "Ley 26.657": 2,
#   "Ley 11.151": 6,
#   "Acuerdo General 14/24": 0,
#   "Ley 6351": 1,
#   "Decreto 958/79": 0,
#   "Ley 27.440": 1,
#   "Ordenanza Municipal 17376": 1,
#   "Ley 7504": 0,
#   "Ley 9234": 1
# }

# %%
clean_idea_central(base_dir)
# Out:
# 📁 Encontrados 295 archivos JSON
# 🚀 Iniciando procesamiento...
#
#
# 📊 RESUMEN:
#    Archivos procesados: 295
#    Archivos modificados: 0
#    Archivos sin modificar: 295
#    Errores: 0
#
# 📋 ARCHIVOS SIN MODIFICAR:
#    - ..\datasets\fallos_json\2024\02\8104.json
#    - ..\datasets\fallos_json\2024\02\8142.json
#    - ..\datasets\fallos_json\2024\02\8344.json
#    - ..\datasets\fallos_json\2024\02\8569.json
#    - ..\datasets\fallos_json\2024\02\8752.json
#    - ..\datasets\fallos_json\2024\02\8865.json
#    - ..\datasets\fallos_json\2024\02\8926.json
#    - ..\datasets\fallos_json\2024\02\8927.json
#    - ..\datasets\fallos_json\2024\02\8948.json
#    - ..\datasets\fallos_json\2024\02\8971.json
#    - ..\datasets\fallos_json\2024\03\8613.json
#    - ..\datasets\fallos_json\2024\03\8840.json
#    - ..\datasets\fallos_json\2024\03\8852.json
#    - ..\datasets\fallos_json\2024\03\8887.json
#    - ..\datasets\fallos_json\2024\03\8903.json
#    - ..\datasets\fallos_json\2024\03\8916.json
#    - ..\datasets\fallos_json\2024\03\8932.json
#    - ..\datasets\fallos_json\2024\03\8939.json
#    - ..\datasets\fallos_json\2024\03\8940.json
#    - ..\datasets\fallos_json\2024\03\8946.json
#    - ..\datasets\fallos_json\2024\03\8947.json
#    - ..\datasets\fallos_json\2024\03\8949.json
#    - ..\datasets\fallos_json\2024\03\8953.json
#    - ..\datasets\fallos_json\2024\03\8959.json
#    - ..\datasets\fallos_json\2024\03\8973.json
#    - ..\datasets\fallos_json\2024\03\8984.json
#    - ..\datasets\fallos_json\2024\03\8985.json
#    - ..\datasets\fallos_json\2024\03\8996.json
#    - ..\datasets\fallos_json\2024\03\8997.json
#    - ..\datasets\fallos_json\2024\03\9019.json
#    - ..\datasets\fallos_json\2024\03\9020.json
#    - ..\datasets\fallos_json\2024\03\9023.json
#    - ..\datasets\fallos_json\2024\03\9024.json
#    - ..\datasets\fallos_json\2024\03\9025.json
#    - ..\datasets\fallos_json\2024\03\9026.json
#    - ..\datasets\fallos_json\2024\03\9029.json
#    - ..\datasets\fallos_json\2024\03\9030.json
#    - ..\datasets\fallos_json\2024\03\9031.json
#    - ..\datasets\fallos_json\2024\03\9032.json
#    - ..\datasets\fallos_json\2024\03\9035.json
#    - ..\datasets\fallos_json\2024\04\8765.json
#    - ..\datasets\fallos_json\2024\04\8771.json
#    - ..\datasets\fallos_json\2024\04\8965.json
#    - ..\datasets\fallos_json\2024\04\8995.json
#    - ..\datasets\fallos_json\2024\04\9001.json
#    - ..\datasets\fallos_json\2024\04\9004.json
#    - ..\datasets\fallos_json\2024\04\9006.json
#    - ..\datasets\fallos_json\2024\04\9056.json
#    - ..\datasets\fallos_json\2024\04\9061.json
#    - ..\datasets\fallos_json\2024\05\8359.json
#    - ..\datasets\fallos_json\2024\05\8362.json
#    - ..\datasets\fallos_json\2024\05\8518.json
#    - ..\datasets\fallos_json\2024\05\8689.json
#    - ..\datasets\fallos_json\2024\05\8713.json
#    - ..\datasets\fallos_json\2024\05\8836.json
#    - ..\datasets\fallos_json\2024\05\8848.json
#    - ..\datasets\fallos_json\2024\05\8861.json
#    - ..\datasets\fallos_json\2024\05\8878.json
#    - ..\datasets\fallos_json\2024\05\8909.json
#    - ..\datasets\fallos_json\2024\05\8914.json
#    - ..\datasets\fallos_json\2024\05\8936.json
#    - ..\datasets\fallos_json\2024\05\8956.json
#    - ..\datasets\fallos_json\2024\05\8967.json
#    - ..\datasets\fallos_json\2024\05\8974.json
#    - ..\datasets\fallos_json\2024\05\8977.json
#    - ..\datasets\fallos_json\2024\05\8980.json
#    - ..\datasets\fallos_json\2024\05\8986.json
#    - ..\datasets\fallos_json\2024\05\8991.json
#    - ..\datasets\fallos_json\2024\05\8999.json
#    - ..\datasets\fallos_json\2024\05\9001.json
#    - ..\datasets\fallos_json\2024\05\9010.json
#    - ..\datasets\fallos_json\2024\05\9011.json
#    - ..\datasets\fallos_json\2024\05\9013.json
#    - ..\datasets\fallos_json\2024\05\9014.json
#    - ..\datasets\fallos_json\2024\05\9017.json
#    - ..\datasets\fallos_json\2024\05\9021.json
#    - ..\datasets\fallos_json\2024\05\9022.json
#    - ..\datasets\fallos_json\2024\05\9027.json
#    - ..\datasets\fallos_json\2024\05\9028.json
#    - ..\datasets\fallos_json\2024\05\9033.json
#    - ..\datasets\fallos_json\2024\05\9034.json
#    - ..\datasets\fallos_json\2024\05\9038.json
#    - ..\datasets\fallos_json\2024\05\9041.json
#    - ..\datasets\fallos_json\2024\06\8344.json
#    - ..\datasets\fallos_json\2024\06\8344r.json
#    - ..\datasets\fallos_json\2024\06\8620.json
#    - ..\datasets\fallos_json\2024\06\8765.json
#    - ..\datasets\fallos_json\2024\06\8851.json
#    - ..\datasets\fallos_json\2024\06\8925.json
#    - ..\datasets\fallos_json\2024\06\8941.json
#    - ..\datasets\fallos_json\2024\06\8951.json
#    - ..\datasets\fallos_json\2024\06\8958.json
#    - ..\datasets\fallos_json\2024\06\8978.json
#    - ..\datasets\fallos_json\2024\06\8981.json
#    - ..\datasets\fallos_json\2024\06\8987.json
#    - ..\datasets\fallos_json\2024\06\8988.json
#    - ..\datasets\fallos_json\2024\06\8989.json
#    - ..\datasets\fallos_json\2024\06\8998.json
#    - ..\datasets\fallos_json\2024\06\9002.json
#    - ..\datasets\fallos_json\2024\06\9010.json
#    - ..\datasets\fallos_json\2024\06\9011.json
#    - ..\datasets\fallos_json\2024\06\9014.json
#    - ..\datasets\fallos_json\2024\06\9015.json
#    - ..\datasets\fallos_json\2024\06\9018.json
#    - ..\datasets\fallos_json\2024\06\9042.json
#    - ..\datasets\fallos_json\2024\06\9043.json
#    - ..\datasets\fallos_json\2024\06\9044.json
#    - ..\datasets\fallos_json\2024\06\9045.json
#    - ..\datasets\fallos_json\2024\06\9047.json
#    - ..\datasets\fallos_json\2024\06\9048.json
#    - ..\datasets\fallos_json\2024\06\9049.json
#    - ..\datasets\fallos_json\2024\06\9050.json
#    - ..\datasets\fallos_json\2024\06\9051.json
#    - ..\datasets\fallos_json\2024\06\9052.json
#    - ..\datasets\fallos_json\2024\06\9053.json
#    - ..\datasets\fallos_json\2024\06\9054.json
#    - ..\datasets\fallos_json\2024\06\9055.json
#    - ..\datasets\fallos_json\2024\06\9058.json
#    - ..\datasets\fallos_json\2024\06\9066.json
#    - ..\datasets\fallos_json\2024\06\9069.json
#    - ..\datasets\fallos_json\2024\06\9070.json
#    - ..\datasets\fallos_json\2024\06\9073.json
#    - ..\datasets\fallos_json\2024\06\9079.json
#    - ..\datasets\fallos_json\2024\06\9080.json
#    - ..\datasets\fallos_json\2024\06\9081.json
#    - ..\datasets\fallos_json\2024\06\9086.json
#    - ..\datasets\fallos_json\2024\06\9087.json
#    - ..\datasets\fallos_json\2024\06\9098.json
#    - ..\datasets\fallos_json\2024\07\8554.json
#    - ..\datasets\fallos_json\2024\07\8941.json
#    - ..\datasets\fallos_json\2024\07\8992.json
#    - ..\datasets\fallos_json\2024\07\9005.json
#    - ..\datasets\fallos_json\2024\07\9008.json
#    - ..\datasets\fallos_json\2024\07\9009.json
#    - ..\datasets\fallos_json\2024\07\9048.json
#    - ..\datasets\fallos_json\2024\07\9071.json
#    - ..\datasets\fallos_json\2024\07\9074.json
#    - ..\datasets\fallos_json\2024\07\9076.json
#    - ..\datasets\fallos_json\2024\07\9084.json
#    - ..\datasets\fallos_json\2024\07\9088.json
#    - ..\datasets\fallos_json\2024\08\7751.json
#    - ..\datasets\fallos_json\2024\08\8439.json
#    - ..\datasets\fallos_json\2024\08\8487.json
#    - ..\datasets\fallos_json\2024\08\8558.json
#    - ..\datasets\fallos_json\2024\08\8642.json
#    - ..\datasets\fallos_json\2024\08\8677.json
#    - ..\datasets\fallos_json\2024\08\8691.json
#    - ..\datasets\fallos_json\2024\08\8748.json
#    - ..\datasets\fallos_json\2024\08\8778.json
#    - ..\datasets\fallos_json\2024\08\8791.json
#    - ..\datasets\fallos_json\2024\08\8926.json
#    - ..\datasets\fallos_json\2024\08\8951.json
#    - ..\datasets\fallos_json\2024\08\8954.json
#    - ..\datasets\fallos_json\2024\08\8956.json
#    - ..\datasets\fallos_json\2024\08\8993.json
#    - ..\datasets\fallos_json\2024\08\9007.json
#    - ..\datasets\fallos_json\2024\08\9040.json
#    - ..\datasets\fallos_json\2024\08\9045.json
#    - ..\datasets\fallos_json\2024\08\9046.json
#    - ..\datasets\fallos_json\2024\08\9062.json
#    - ..\datasets\fallos_json\2024\08\9063.json
#    - ..\datasets\fallos_json\2024\08\9068.json
#    - ..\datasets\fallos_json\2024\08\9077.json
#    - ..\datasets\fallos_json\2024\08\9078.json
#    - ..\datasets\fallos_json\2024\08\9083.json
#    - ..\datasets\fallos_json\2024\08\9085.json
#    - ..\datasets\fallos_json\2024\08\9092.json
#    - ..\datasets\fallos_json\2024\08\9094.json
#    - ..\datasets\fallos_json\2024\08\9095.json
#    - ..\datasets\fallos_json\2024\08\9096.json
#    - ..\datasets\fallos_json\2024\08\9099.json
#    - ..\datasets\fallos_json\2024\08\9103.json
#    - ..\datasets\fallos_json\2024\08\9107.json
#    - ..\datasets\fallos_json\2024\08\9108.json
#    - ..\datasets\fallos_json\2024\08\9112.json
#    - ..\datasets\fallos_json\2024\08\9118.json
#    - ..\datasets\fallos_json\2024\09\6424.json
#    - ..\datasets\fallos_json\2024\09\8439.json
#    - ..\datasets\fallos_json\2024\09\8756.json
#    - ..\datasets\fallos_json\2024\09\8778.json
#    - ..\datasets\fallos_json\2024\09\8886.json
#    - ..\datasets\fallos_json\2024\09\8981.json
#    - ..\datasets\fallos_json\2024\09\8982.json
#    - ..\datasets\fallos_json\2024\09\8990.json
#    - ..\datasets\fallos_json\2024\09\8999.json
#    - ..\datasets\fallos_json\2024\09\9036.json
#    - ..\datasets\fallos_json\2024\09\9039.json
#    - ..\datasets\fallos_json\2024\09\9042.json
#    - ..\datasets\fallos_json\2024\09\9047.json
#    - ..\datasets\fallos_json\2024\09\9059.json
#    - ..\datasets\fallos_json\2024\09\9067.json
#    - ..\datasets\fallos_json\2024\09\9082.json
#    - ..\datasets\fallos_json\2024\09\9100.json
#    - ..\datasets\fallos_json\2024\09\9115.json
#    - ..\datasets\fallos_json\2024\09\9135.json
#    - ..\datasets\fallos_json\2024\10\7351.json
#    - ..\datasets\fallos_json\2024\10\8500.json
#    - ..\datasets\fallos_json\2024\10\8543.json
#    - ..\datasets\fallos_json\2024\10\8628.json
#    - ..\datasets\fallos_json\2024\10\8729.json
#    - ..\datasets\fallos_json\2024\10\8941.json
#    - ..\datasets\fallos_json\2024\10\8961.json
#    - ..\datasets\fallos_json\2024\10\8962.json
#    - ..\datasets\fallos_json\2024\10\8980.json
#    - ..\datasets\fallos_json\2024\10\9057.json
#    - ..\datasets\fallos_json\2024\10\9072.json
#    - ..\datasets\fallos_json\2024\10\9075.json
#    - ..\datasets\fallos_json\2024\10\9089.json
#    - ..\datasets\fallos_json\2024\10\9096.json
#    - ..\datasets\fallos_json\2024\10\9101.json
#    - ..\datasets\fallos_json\2024\10\9105.json
#    - ..\datasets\fallos_json\2024\10\9106.json
#    - ..\datasets\fallos_json\2024\10\9109.json
#    - ..\datasets\fallos_json\2024\10\9110.json
#    - ..\datasets\fallos_json\2024\10\9111.json
#    - ..\datasets\fallos_json\2024\10\9113.json
#    - ..\datasets\fallos_json\2024\10\9117.json
#    - ..\datasets\fallos_json\2024\10\9120.json
#    - ..\datasets\fallos_json\2024\10\9121.json
#    - ..\datasets\fallos_json\2024\10\9123.json
#    - ..\datasets\fallos_json\2024\10\9124.json
#    - ..\datasets\fallos_json\2024\10\9125.json
#    - ..\datasets\fallos_json\2024\10\9126.json
#    - ..\datasets\fallos_json\2024\10\9127.json
#    - ..\datasets\fallos_json\2024\10\9128.json
#    - ..\datasets\fallos_json\2024\10\9130.json
#    - ..\datasets\fallos_json\2024\10\9132.json
#    - ..\datasets\fallos_json\2024\10\9134.json
#    - ..\datasets\fallos_json\2024\10\9137.json
#    - ..\datasets\fallos_json\2024\10\9140.json
#    - ..\datasets\fallos_json\2024\10\9142.json
#    - ..\datasets\fallos_json\2024\10\9149.json
#    - ..\datasets\fallos_json\2024\10\9150.json
#    - ..\datasets\fallos_json\2024\10\9152.json
#    - ..\datasets\fallos_json\2024\11\7351.json
#    - ..\datasets\fallos_json\2024\11\8131.json
#    - ..\datasets\fallos_json\2024\11\8518.json
#    - ..\datasets\fallos_json\2024\11\8678.json
#    - ..\datasets\fallos_json\2024\11\8792.json
#    - ..\datasets\fallos_json\2024\11\8935.json
#    - ..\datasets\fallos_json\2024\11\8973.json
#    - ..\datasets\fallos_json\2024\11\9012.json
#    - ..\datasets\fallos_json\2024\11\9060.json
#    - ..\datasets\fallos_json\2024\11\9064.json
#    - ..\datasets\fallos_json\2024\11\9065.json
#    - ..\datasets\fallos_json\2024\11\9070.json
#    - ..\datasets\fallos_json\2024\11\9075.json
#    - ..\datasets\fallos_json\2024\11\9077.json
#    - ..\datasets\fallos_json\2024\11\9079.json
#    - ..\datasets\fallos_json\2024\11\9109.json
#    - ..\datasets\fallos_json\2024\11\9114.json
#    - ..\datasets\fallos_json\2024\11\9116.json
#    - ..\datasets\fallos_json\2024\11\9119.json
#    - ..\datasets\fallos_json\2024\11\9129.json
#    - ..\datasets\fallos_json\2024\11\9139.json
#    - ..\datasets\fallos_json\2024\11\9144.json
#    - ..\datasets\fallos_json\2024\11\9153.json
#    - ..\datasets\fallos_json\2024\11\9158.json
#    - ..\datasets\fallos_json\2024\11\9160.json
#    - ..\datasets\fallos_json\2024\11\9161.json
#    - ..\datasets\fallos_json\2024\11\9164.json
#    - ..\datasets\fallos_json\2024\11\9165.json
#    - ..\datasets\fallos_json\2024\11\9169.json
#    - ..\datasets\fallos_json\2024\11\9172.json
#    - ..\datasets\fallos_json\2024\12\6424.json
#    - ..\datasets\fallos_json\2024\12\8206.json
#    - ..\datasets\fallos_json\2024\12\8544.json
#    - ..\datasets\fallos_json\2024\12\8630.json
#    - ..\datasets\fallos_json\2024\12\8711.json
#    - ..\datasets\fallos_json\2024\12\8935.json
#    - ..\datasets\fallos_json\2024\12\8977.json
#    - ..\datasets\fallos_json\2024\12\8983.json
#    - ..\datasets\fallos_json\2024\12\9016.json
#    - ..\datasets\fallos_json\2024\12\9018.json
#    - ..\datasets\fallos_json\2024\12\9076.json
#    - ..\datasets\fallos_json\2024\12\9083.json
#    - ..\datasets\fallos_json\2024\12\9084.json
#    - ..\datasets\fallos_json\2024\12\9094.json
#    - ..\datasets\fallos_json\2024\12\9096.json
#    - ..\datasets\fallos_json\2024\12\9098.json
#    - ..\datasets\fallos_json\2024\12\9116.json
#    - ..\datasets\fallos_json\2024\12\9128.json
#    - ..\datasets\fallos_json\2024\12\9136.json
#    - ..\datasets\fallos_json\2024\12\9141.json
#    - ..\datasets\fallos_json\2024\12\9146.json
#    - ..\datasets\fallos_json\2024\12\9155.json
#    - ..\datasets\fallos_json\2024\12\9162.json
#    - ..\datasets\fallos_json\2024\12\9171.json
#    - ..\datasets\fallos_json\2024\12\9173.json
#    - ..\datasets\fallos_json\2024\12\9175.json
#    - ..\datasets\fallos_json\2024\12\9180.json
#    - ..\datasets\fallos_json\2024\12\9190.json
#    - ..\datasets\fallos_json\2024\12\9192.json
#    - ..\datasets\fallos_json\2024\12\9194.json
#    - ..\datasets\fallos_json\2024\12\9211.json
#
# 🎉 Proceso completado!

# %%
output_base_dir = "../datasets/fallos_json_modificados"
output_stats_modified = "main_source_cited_articles_stats_modified.json"

normalizar_json(base_dir, output_base_dir)
# Out:
# Archivos .json modificados guardados en la carpeta 'fallos_json_modificados', replicando la estructura original.

# %%
create_json_stats(output_base_dir, output_stats_modified)
# Out:
# Archivo 'main_source_cited_articles_stats_modified.json' generado correctamente.

# %%
print_json_stats_summary(output_stats_modified)
# Out:
# {
#   "Ley 7046": 723,
#   "Acuerdo General 15/18 SNE": 505,
#   "Código Civil y Comercial (CCC)": 414,
#   "Ley 19.550": 3,
#   "Código Procesal Civil y Comercial (CPCC)": 718,
#   "Acuerdo General 11/20": 32,
#   "Ley 24.449": 54,
#   "Corte Suprema de Justicia de la Nación (CSJN)": 74,
#   "Constitución Nacional (CN)": 144,
#   "Otro": 180,
#   "Ley 10.636": 1,
#   "Ley 5796": 1,
#   "Código Procesal Civil y Comercial de Entre Ríos (CPCCER)": 15,
#   "Ley 48": 15,
#   "Acordada 4/2007": 47,
#   "Ley 25.529": 6,
#   "Ley 4878": 8,
#   "Ley 27.423": 2,
#   "Ley 9776": 1,
#   "Código Procesal Penal (CPP)": 23,
#   "Ley 23.737": 6,
#   "Acuerdo General 28/20": 1,
#   "Ley 6902": 4,
#   "Constitución Provincial de Entre Ríos": 25,
#   "Ley 10.704": 179,
#   "Reglamento de Presentaciones Electrónicas": 6,
#   "Ley 10.668": 2,
#   "Ley 26.485": 5,
#   "Ley 10.855": 2,
#   "Ley 9861": 4,
#   "Ley 26.061": 9,
#   "Resolución 170/19": 6,
#   "Ley 24.522 (LCQ - Ley de Concursos y Quiebras)": 28,
#   "Convención Americana de Derechos Humanos (Pacto de San José de Costa Rica)": 13,
#   "Convención sobre los Derechos de las Personas Adultas Mayores": 4,
#   "Ley 14.159": 1,
#   "Ley 26.487": 1,
#   "Convención sobre los Derechos del Niño": 3,
#   "Guía de Buenas Prácticas": 2,
#   "Corte Interamericana de Derechos Humanos": 6,
#   "Ley 10.956": 2,
#   "Ley 10.407": 1,
#   "Resolución Tribunal Superior 340/2023 DGA": 1,
#   "Acuerdo General 28/15": 7,
#   "Ley 26.657": 2,
#   "Ley 11.151": 6,
#   "Acuerdo General 14/24": 0,
#   "Ley 6351": 1,
#   "Decreto 958/79": 0,
#   "Ley 27.440": 1,
#   "Ordenanza Municipal 17376": 1,
#   "Ley 7504": 0,
#   "Ley 9234": 1
# }

# %% [markdown]
# ## Actualizar a fallos_json_modificados a fallos_json y dejar el anterior como fallos_json_old

# %%
# =============================================
# Función para renombrar carpetas (ver comentario)
# =============================================

def renombrar_carpetas(carpeta_a_old, carpeta_b_a):
    """
    Renombra la carpeta 'carpeta_a_old' agregando '_old' al final y luego renombra 'carpeta_b_a' con el nombre original de 'carpeta_a_old'.
    Args:
        carpeta_a_old (str): Ruta de la carpeta que se marcará como old.
        carpeta_b_a (str): Ruta de la carpeta que tomará el nombre de la anterior.
    """
    import os
    from pathlib import Path

    carpeta_a_old = Path(carpeta_a_old)
    carpeta_b_a = Path(carpeta_b_a)

    # Nuevo nombre para la carpeta vieja
    carpeta_a_old_dest = carpeta_a_old.parent / (carpeta_a_old.name + '_old')

    # Renombrar la carpeta original a *_old
    if carpeta_a_old.exists():
        os.rename(carpeta_a_old, carpeta_a_old_dest)
        print(f"Renombrada {carpeta_a_old} a {carpeta_a_old_dest}")
    else:
        print(f"No existe la carpeta: {carpeta_a_old}")
        return

    # Renombrar la carpeta nueva al nombre original
    if carpeta_b_a.exists():
        os.rename(carpeta_b_a, carpeta_a_old)
        print(f"Renombrada {carpeta_b_a} a {carpeta_a_old}")
    else:
        print(f"No existe la carpeta: {carpeta_b_a}")

# %%
renombrar_carpetas(carpeta_a_old=base_dir, carpeta_b_a=output_base_dir)
# Out:
# Renombrada ..\datasets\fallos_json a ..\datasets\fallos_json_old
# Renombrada ..\datasets\fallos_json_modificados a ..\datasets\fallos_json
